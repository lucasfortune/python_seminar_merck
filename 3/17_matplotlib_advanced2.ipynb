# %% [markdown]
# # Python Data Visualization
# ## Matplotlib - Advanced
# ***
# This notebook covers:
# - Axis labeling & Legends
# - Text, fonts and LaTeX
# - Contour plots
# - Polar plots
# ***

# %% [markdown]
# #### Please run the following cell first

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Axis Labels and Legend
#  There are three important methods to adjust the axes in a plot: <br>
# - `xlim`: to limit the value range of the x-axis <br>
# - `xticks`: to change the marks on the axis <br>
# - `xticklabels`: to set the labels on the axis <br>
#  For the y-axis there are the corresponding methods: `ylim`, `yticks`, `yticklabels`. <br>
#  To retrieve the set values: <br>
# - `plt.get_xlim` <br>
# - `plt.get_xticks` <br>
# - `plt.get_xticklabels` <br>
#  To set these values: <br>
# - `plt.set_xlim([start, end])` <br>
# - `plt.set_xticks(meineTicks)` <br>
# - `plt.set_xticklabels(meineBeschriftungen)` <br>
#  The method **`cumsum`**, applied to a `numpy` array, returns a new array with the cumulative sums of the columns. <br>
# #### 1.1 Exercises:
# > (a) Create a figure **`fig`** and a plot **`ax1`** <br>
# >
# > (b) Create 3 series of values named **`s1`**, **`s2`**, **`s3`**, where each is the cumulative sum of 50 random values generated with **`np.random.randn`** <br>
# >
# > (c) Draw the 3 corresponding curves with the colors ('#33CCFF', '#FFCC99', '#FF33CC'), line style '-.' and the labels 'Curve 1', 'Curve 2', 'Curve 3' <br>
# >
# > (d) Limit the values of the x-axis to [0, 21] and the y-axis to [-15, 15] using the functions `ax1.set_xlim` and `ax1.set_ylim` <br>
# >
# > (e) Label the x-axis with a distance of two between the marks (instead of five) using the function `ax1.set_xticks` <br>
# >
# > (f) Change the labels to **'d + i'** for **i** between 0 and 20 (with step size 2) <br>
# >
# > (g) Give the x-axis the title 'Duration after day d' <br>
# >
# > (h) Display the legends at the best location in the graph <br>
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i> &emsp;
# Remember that before looking at the solution you can find a hint in the official Python documentation by entering <code style = "background-color: transparent ; color : inherit"><b>help(functionname)</b></code> in the console.
# </div>

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(111)
s1 = np.random.randn(30).cumsum()
s2 = np.random.randn(30).cumsum()
s3 = np.random.randn(30).cumsum()
# We create the series of values
ax1.plot(s1,color='#33CCFF',marker='o',linestyle='-.',label='Kurve 1')
ax1.plot(s2,color='#FFCC99',marker='o',linestyle='-.',label='Kurve 2')
ax1.plot(s3,color='#FF33CC',marker='o',linestyle='-.',label='Kurve 3')
# We draw the curves
ax1.set_xlim([0,21])
ax1.set_ylim([-15,15])
# We limit the axes
ax1.set_xticks(range(0,21,2))
# We label the axis with step size two (instead of five)
ax1.set_xticklabels(["j +" + str(l) for l in range(0,21,2)])
# We change the labels
ax1.set_xlabel('Dauer nach Tag j')
ax1.legend(loc='best');
# Choose the best position for the legend

# %% [markdown]
# ## 2. Plot_date
#  `Matplotlib` contains a function `plot_date`, which allows using dates as x or y values. <br>
#  The module *datetime* can create dates or date sequences in the following format: (year, month, day, hour, minutes, seconds). <br>
#  The function `plot_date` takes as arguments a sequence of dates, a sequence of values of equal length and parameters like `linestyle`. Without the latter, no line is drawn between the markers. <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Using the function **plot_date** </span><br>
#  The following code <br>
# ```python
# import datetime as dt
# fig = plt.figure( figsize = (12, 4))
# ax1 = fig.add_subplot(111)
# dates = [dt.datetime(2017,1,17) + dt.timedelta(days=i) for i in range(10)]
# werte = np.random.rand(len(dates))
# ax1.plot_date(dates, werte, linestyle='-')
# ```
#  produces: <br>
#  <img src="../imgs/dates.png" style="height:200px"> <br>
#  `Matplotlib` offers various possibilities for formatting the axes. Dates can also be displayed in different formats, but we will not go into these details in this exercise. <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Different date formats </span><br>
#  <img src="../imgs/dates2.png" style="height:250px">
# #### 2.1 Exercises:
# > (a) Create using the above code a figure of size (12, 4), add a graph that starts on January 1, 2016 and takes random values every 31 days until December 2016. <br>
# <div class="alert alert-success"> &emsp;
# The command <b>dt.timedelta</b> allows adding a certain number of days, hours, seconds, etc. to a date
# </div>
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i> &emsp;
# Remember that before looking at the solution you can always access the official Python documentation by entering <code style = "background-color: transparent ; color : inherit"><b>help(functionname)</b></code> in the console.
# </div>

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
import datetime as dt

dates = [dt.datetime(2017,1,17) + dt.timedelta(days=i) for i in range(10)]
print(dates)

fig = plt.figure( figsize = (12, 4))
ax1 = fig.add_subplot(111)

werte = np.random.rand(len(dates))
ax1.plot_date(dates, werte, linestyle='-');
# Out:
# [datetime.datetime(2017, 1, 17, 0, 0), datetime.datetime(2017, 1, 18, 0, 0), datetime.datetime(2017, 1, 19, 0, 0), datetime.datetime(2017, 1, 20, 0, 0), datetime.datetime(2017, 1, 21, 0, 0), datetime.datetime(2017, 1, 22, 0, 0), datetime.datetime(2017, 1, 23, 0, 0), datetime.datetime(2017, 1, 24, 0, 0), datetime.datetime(2017, 1, 25, 0, 0), datetime.datetime(2017, 1, 26, 0, 0)]
# /var/folders/9x/t526dchn0v15vnm8m6q_8ct40000gn/T/ipykernel_50730/2309106152.py:10: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   ax1.plot_date(dates, werte, linestyle='-');

# %% [markdown]
# ## 3. Text, Fonts and LaTeX
#  `Matplotlib` allows complete control over text properties (font, size, position, color...). With `Matplotlib` it is possible to display mathematical symbols in any figure using **LaTeX** commands. <br>
#  Some text functions were already introduced earlier, but here is a complete list of `pyplot` functions that can be used to insert text. We present them with the objects '**`fig`**' and '**`ax`**'. <br>
# * `text` <=> `ax.text`: Inserts text at any position in '`ax`'. <br>
# * `xlabel` <=> `ax.set_xlabel`: Adds a label to the x-axis of '`ax`'. <br>
# * `ylabel` <=> `ax.set_ylabel`: Adds a label to the y-axis of '`ax`'. <br>
# * `title` <=> `ax.set_title`: Adds a title to '`ax`'. <br>
# * `figtext` <=> `fig.text`: Adds a title to '`fig`'. <br>
# * `suptitle` <=> `fig.suptitle`: Adds a centered title to '`fig`'. <br>
# * `annotate` <=> `ax.annotate`: Adds an annotation and arrow to '`ax`'. <br>
#  All these commands return a `Text` object. The text can be customized by passing arguments to functions or by using `matplotlib.artist.setp` or `plt.setp`. <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Text customization </span><br>
# ```python
# t = plt.xlabel('A label', fontsize=16, color='green')
# ```
#  is equivalent to <br>
# ```python
# t = plt.xlabel('A label')
# setp(t, fontsize=16, color='green')
# ```
#  The text font can be changed with the parameter `family`. <br>
#  There are 6 available font families for the texts: 'serif', 'sans-serif', 'cursive', 'fantasy' and 'monospace'. <br>
#  The font style can also be changed with `fontstyle` and can be: 'normal', 'italic' or 'oblique'. <br>
#  One can access the text objects of a graph with functions like `ax.get_xticklabels`, which returns the labels of the x-axis markers. <br>
#  With object parameters it is possible to assign the same properties to all objects in the same group. <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Group objects </span><br>
# ```python
# for t in ax.get_xticklabels():
#     t.set_fontsize(5.)
# ```
#  With `setp`: <br>
# ```python
# plt.setp(ax.get_xticklabels(), fontsize=5.)
# ```
#  The font size of all x-axis labels was changed. <br>
# #### 3.1 Exercises:
# > (a) Create a figure of size (6, 6) and a graph. Set the title to "My Title" as an object named **`t`** <br>
# >
# > (b) Add in the graph the text 'Hello' at point `(0.2,0.8)` and 'Hello2' at point `(0.7, 0.2)` and return both in a list of 'Text' objects named **'`texts`'** <br>
# >
# > (c) Change the title using `setp` and set a red color with a font size of 16 <br>
# >
# > (d) Change the texts using `setp` and set the font to 'serif' in blue color

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
fig = plt.figure(figsize=(3, 3))
ax = fig.add_subplot(111)
t = ax.set_title('Title')
texts = [ax.text(0.2, 0.8, 'Hello'), ax.text(0.7, 0.2, 'Hello2')]
# 'Text' objects are returned in a list
plt.setp(t, color='red', fontsize=16)
plt.setp(texts, family='serif', color='blue');
# The command 'setp' can set parameters of all
# elements in the list 'texts'

# %% [markdown]
# ####
# Matplotlib allows displaying text in **LaTeX** format. You must prefix the string with an 'r', enclose it with the symbol '\$' and use the functions and mathematical symbols that are available [here](https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols). <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Text in **LaTeX** format </span><br>
# ```python
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.text(0.1, 0.5, r"$ f(x,y) = x^2 + 3 \times \cos(y) $", fontsize=22)
# ```
#  displays the following graph: <br>
#  <img src="../imgs/tex.png" style="height:250px"> <br>
#  Use the previous exercises and the [documentation](https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols) on $\LaTeX$ symbols to reproduce the following image: <br>
#  <img src='../imgs/Exotext.png' style="height:300px"> <br>
# > (e) Draw in a graph the functions and asymptotes in the interval [0, 5] <br>
# >
# > (f) Display the four local minima (function values for $x = 3/4 +k, k \in [0,4]$) with diamond symbols ('D') <br>
# >
# > (g) Add the text 'Local Minima' to the point `(3, -0.5)` <br>
# >
# > (h) Add title and display the legend

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
x = np.arange(0., 5., .01)
# We create a sequence for the x-axis
y = np.sin(2*np.pi*x) * np.exp(-x)
# Function to display
fig = plt.figure()
ax = fig.add_subplot(111)
# We create figure and graph
ax.plot(x, y, label='$\sin(2\pi x)\exp(-x)$')
ax.plot(x, np.exp(-x), label='$\exp(-x)$')
ax.plot(x, -np.exp(-x), label='$-\exp(-x)$')
# We draw the function and its asymptotes. Then we label them.
p = [3/4 + k for k in range(4)]
# We calculate the 4 local minima
ax.plot(p, [-np.exp(-k) for k in p], 'Dc')
# We draw the local minimum points
ax.text(3, -0.5, 'Local Minima', color='c')
# We add the text 'Local Minima'
ax.set_title('$\sin(2\pi x)\exp(-x)$ and the 2 asymptotes $\pm\exp(-x)$')
# We add the title with some LaTeX parts
ax.legend();
# We add the legend

# %% [markdown]
# ## 4. Contour Plots
#  The function `plt.contour` allows the display of contour plots. <br>
#  In the case of a function with two variables, we also call them contour lines or isolines. On such a line, the function value is constant. <br><br>
#  Mathematically speaking, a contour line represents f(x, y) = L for various constant values of L. <br>
#  To draw contour lines, two number sequences **x** and **y** with sizes **m** and **n** respectively are instantiated, representing coordinate vectors. Then a two-dimensional grid must be created that stores the coordinate matrices from the combination of **x** and **y**. This is done with the function **`np.meshgrid`**, which returns two arrays **X** and **Y** of size **n x m**. <br><br>
#  Then standard arithmetic operations can be performed on these matrices to create a surface **Z** that contains the values of the function to be drawn. <br>
#  The command `plt.contour(X,Y,Z)` draws contour lines using X and Y as coordinates. It is possible to specify the number of lines to be drawn or even the values of the lines. <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Contour curves </span><br>
# ```python
# x = np.arange(-1,1,0.05)
# y = np.arange(-2, 2, 0.05)
# X,Y = np.meshgrid(x,y)
# Z = Y**2 - X**2
# plt.contour(X,Y,Z)
# ```
#  produces the following output: <br>
# <img src='../imgs/cont1.png' style='height:250px'> <br>
#  It is also possible to display the value of the lines in the graph using **`plt.clabel`**. <br>
# #### 4.1 Exercises:
# > (a) Create two sequences **x** and **y** with values between [-2;2] and a step size of 0.01 <br>
# >
# > (b) Create coordinate matrices **X** and **Y** with the function **`np.meshgrid`** <br>
# >
# > (c) Create matrix $Z = X*X/9 + Y*Y/4 - 1$ <br>
# >
# > (d) Create the contour lines of **`Z`** under the name **`cs`** <br>
# >
# > (e) Display the values of **`cs`** in the graph using the function **`clabel`**

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
x = np.arange(-2, 2, 0.01)
y = np.arange(-2, 2, 0.01)
X, Y = np.meshgrid(x, y)
Z = X*X/9 + Y*Y/4 - 1
cs = plt.contour(X,Y,Z)
plt.clabel(cs);

# %% [markdown]
# ####
# > (f) Create two sequences **`x`** and **`y`**, which contain 50 values **between -2$\pi$ and 2$\pi$** and 50 values **between 0 and 4$\pi$** respectively, using the function **`np.linspace`** <br>
# >
# > (g) Create the coordinate matrices **`X`** and **`Y`** with the function **`np.meshgrid`** <br>
# >
# > (h) Create matrix **$Z = \sin{X}+ \cos{Y}$** <br>
# >
# > (i) Display 10 contour lines of **`Z`** <br>
# >
# > (j) Add the title 'Contour Plot' <br>
# >
# > (k) Add the labels '`x`' and '`y`' to the axes

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
x = np.linspace(-2*np.pi,2*np.pi)
y = np.linspace(0,4*np.pi)
[X,Y] = np.meshgrid(x,y)
Z = np.sin(X)+np.cos(Y)
cp = plt.contour(X,Y,Z,10)
plt.xlabel('x')
plt.ylabel('y');

# %% [markdown]
# ####
# The method **`contourf`** works the same way as the method **`contour`**, but allows creating colored areas between the lines. <br>
#  Each color represents a value of the function. The method **`plt.colorbar`** allows displaying a color bar with the corresponding values. <br>
# > (l) Create two sequences **`x`** and **`y`**, which contain 200 values **between -1 and 1** and 200 values **between -1 and 2** respectively, using **`np.linspace`** <br>
# >
# > (m) Create the coordinate matrices **`X`** and **`Y`** with **`np.meshgrid`** <br>
# >
# > (n) Create the output matrix **`Z`**, defined by the Rosenbrock function: **$Z = (1-x)^2+(y-x^2)^2$** <br>
# >
# > (o) Display the colored *contour plot* of **`Z`** as well as a color bar <br>
# >
# > (p) Set the title to **'Rosenbrock Function'**

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
x, y = np.linspace(-1,1,200), np.linspace(-1,2,200)
X, Y = np.meshgrid(x,y)
Z = (1-X)**2+(Y-X**2)**2
plt.contourf(X,Y,Z,20)
plt.colorbar()
plt.title('Rosenbrock-Function');

# %% [markdown]
# ## 5. Polar Plots
#  Polar plots use a completely different coordinate system. Up to now we have only used Cartesian coordinates, where two orthogonal axes intersect at the origin and define precise directions for positive and negative values. A polar system is a 2D coordinate system where the position of a point is expressed by radius and angle. <br><br>
#  This system is used when the relationship between two points can be better expressed in this coordinate system. <br><br>
#  A point is represented by a radial and an angular component. The radial coordinate, often referred to as **r**, is called radius. It expresses the distance to the origin (the pole). The angular coordinate, denoted as θ, is called polar angle. It expresses the measure of the angle between the point and the 0° half-line (the polar axis, similar to the x-axis) in trigonometric direction (positive direction). <br><br>
#  The function `polar` from `Matplotlib` displays polar plots. Its parameters are 2 lists of equal size, `theta` for the angular coordinates and `r` for the radial coordinates. It is the equivalent to `plot` for polar plots. <br><br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Polar coordinates </span><br>
# ```python
# theta = np.arange(0, 2, 1/180)*np.pi
# plt.polar(3*theta, theta/5)
# plt.polar(theta, np.cos(4*theta))
# plt.polar(theta, [1.4]*len(theta));
# ```
#  produces <br>
# <img src='../imgs/polplot.png' style='heigth=150px'> <br>
#  In the example we define **`theta`** as a sequence of 360 equidistant values between 0 and 2$\pi$. The second line draws a spiral. Below that we draw a **rosette**. <br>
#  In the polar coordinate system, r must remain constant (here equal to 1.4) to draw a circle. <br>
# #### 5.1 Exercises:
# > (a) Create a sequence **`theta`** of 360 equidistant values between 0 and 2$\pi$ <br>
# >
# > (b) Display the polar plot of **`theta`** and $r = 4 * \cos(12 * \theta)$

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
theta = np.arange(0, 2, 1./180.)*np.pi 
plt.polar(theta, 4*np.cos(12*theta));

# %% [markdown]
# ####
# To control the grid there are two functions: `rgrid` and `thetagrid`. <br>
#  `rgrids` takes as input: <br>
# * *radii*: Radial distances between radial grid lines (concentric dotted circles) <br>
# * *labels*: Labels to print on the grid <br>
# * *angle*: The angles at which labels are printed (by default 22.5°) <br>
#  `thetagrids` takes as input: <br>
# * *angles*: Where labels should be printed <br>
# * *labels*: Labels to be printed <br>
# * *frac*: Radius fraction of the label position (1 prints labels at the edge, 1.1 prints labels outside the graph and 0.9 prints labels inside) <br>
# > (c) Create a sequence **`theta`** of 360 equidistant values between 0 and 2$\pi$ <br>
# >
# > (d) Create **r = |sin(5 × theta) - 2 cos(theta)|**, where **|.|** represents the absolute value, which is calculated with the function **`np.abs`** <br>
# >
# > (e) Display the polar plot of **`theta`** and **`r`** <br>
# >
# > (f) Draw grid lines between the radial distances `0.2` and `3.1` with a step size of `0.7` using the function **`rgrids`** <br>
# >
# > (g) Display angle labels from `45°` to `360°` with a step size of `90°` using the corresponding function for the angles

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
theta = np.arange(0., 2., 1./180.)*np.pi 
r = np.abs(np.sin(5*theta) - 2.*np.cos(theta))
plt.polar(theta, r)
plt.rgrids(np.arange(0.2, 3.1, .7), angle=0)
plt.thetagrids(np.arange(45, 360, 90));

# %% [markdown]
# ####
# Without using the function `polar`, it is possible to change the coordinate system when creating a graph with the argument `projection='polar'`. <br>
#  Afterwards, curves, points and other graphs can be displayed in it with the usual commands. <br>
#  <span style="color:#09b038; text-decoration : underline"> Example: Using the argument *projection='polar'* </span><br>
#  The code <br>
# ```python
# ax = plt.subplot(111, projection='polar')
# plt.plot(theta, r)
# ```
#  displays the same graph as before: <br>
# <img src='../imgs/pap.png' style='height:200px'> <br>
# > (h) Create a sequence **`r`** of 150 random numbers with the function **`np.random.rand`**, multiplied by **`2`** <br>
# >
# > (i) Create a sequence **`theta`** of 150 random numbers with the function **`np.random.rand`**, multiplied by **2$\pi$** <br>
# >
# > (j) Create a sequence **`sizes`** of 150 random numbers with the function **`np.random.rand`**, multiplied by **200 $ \times$ $r^2$** <br>
# >
# > (k) Create a plot with the function **`plt.subplot`** and specify the polar projection <br>
# >
# > (l) Display a *scatter plot* with the coordinates `theta` and `r` and the parameters `c=theta`, `s=sizes` and `cmap=plt.cm.hsv` (to use a different *color map*)

# %%
# Your Solution:

# %% [markdown]
# #### Solution:

# %%
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
sizes = 200 * r**2 * np.random.rand(N)

ax = plt.subplot(111, projection='polar')
# We create an empty polar plot

c = plt.scatter(theta, r, c=theta, s=sizes, cmap=plt.cm.hsv)
# And add the points with random size and color
