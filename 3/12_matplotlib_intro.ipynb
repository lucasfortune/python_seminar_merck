# %% [markdown]
# # Python Data Visualization 1
# ## Matplotlib
# ***
# This notebook covers:
# - Creating line charts
# - Charts with multiple lines
# ***

# %% [markdown]
# ## Introduction to Data Visualization with Matplotlib
#
# ### Introduction
#
# In the following notebooks, we will work with data visualization using the **Matplotlib** module. <br>
#
# Matplotlib is a powerful Python library for plotting and visualizing data. It is used to create all types of graphs. <br>
#
# With the Matplotlib submodule **`pyplot`**, creating graphs is very similar to working in Matlab. <br>
#
# Matplotlib is a very extensive library, so not all functions can be presented. We will focus on the most important functions, with the main goal that you can work independently with the library by the end of the course. <br>
#
# To begin, we import the `matplotlib.pyplot` module under the alias 'plt'. <br>
#
# Once the graph is fully defined, it can be visualized with the `plt.show` command. In the following exercises, we will also use the **numpy** and **pandas** libraries. <br>
#
# We therefore start all Matplotlib notebooks with the following cell: <br>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Creating Line Charts
#
# A line chart is a set of points with coordinates (x, y), between which a line is drawn: The more points used, the smoother the plot looks. <br>
#
# The **`plot`** function allows you to draw lines that connect points, whose X and Y coordinates are provided in lists or arrays. To draw a graph with values '`x`' on the X-axis and values '`y`' on the Y-axis, we write:
#
# ```python
# x = [1,2,3]
# y = [1,2,3]
# plt.plot(x,y)
# ```
#
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i>
#  Note: X-axis refers to the horizontal axis and Y-axis to the vertical axis.
# </div>
#
# #### 1.1 Tasks:
# > (a) Draw a line chart with X-coordinates [0,2,4,6] and Y-coordinates [1,4,4,8]. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
plt.plot([0,2,4,6],[1,4,4,8]);

# %% [markdown]
# ####
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i>
# Note: Adding a '<b>;</b>' to the last line of each cell prevents unwanted text outputs above the plot. This is not Python syntax, but a leftover from Matlab.
# </div>
#
# When only one list or array is passed to the plot function, Matplotlib assumes it is a sequence of Y-values and automatically generates the X-axis values. The X-axis values are set as positions of the Y-values starting at 0. <br>
#
# > (b) Draw a line from the list: [1,3,2,4]. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
liste = [1, 3, 2, 4]
plt.plot(liste);

# %% [markdown]
# ####
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i>
#  Note: Only the Y-values were passed, the X-values were automatically set to [0,1,2,3].
# </div>
#
# To add a title to graphs, we use the **`title`** method. <br>
# To add labels to the axes, we use the **`xlabel`** and **`ylabel`** methods. <br>
#
# > (c) Draw a line chart through the following points: `(50,1) , (140,2) , (200,4)`. <br>
# >
# > (d) Give the figure the title 'My first line chart'. <br>
# >
# > (e) Label the X- and Y-axis with 'X-axis' and 'Y-axis'. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
plt.title('My first line diagram')
plt.plot([50,140,200], [1,2,4])
plt.xlabel('X axis')
plt.ylabel('Y axis');

# %% [markdown]
# ####
# It is possible to use the **`axis`** method to control the axis length. It is used as follows: `axis([xmin, xmax, ymin, ymax])`. To control the X-axis or Y-axis independently, you can use `xlim([xmin, xmax])` or `ylim([ymin, ymax])`. <br>
#
# > (f) Draw a line chart through the following points: `(50,1) , (140,2) , (200,4)`. <br>
# >
# > (g) The graph should have X-values between 80 and 180 and Y-values from 1 to 5. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
plt.plot([50,140,200], [1,2,4])
plt.axis([80, 180, 1, 5]);

# or:
#plt.xlim([80,180]); 
#plt.ylim([1,5])

# %% [markdown]
# ####
# The `plot` function only connects points in the order we specify them. It is possible to specify multiple points with the same X-coordinates to create a shape. <br>
#
# > (h) Create the lists **`x`** and **`y`** as follows: `x = [0, 0, 1, 1, 0, 0.5, 1]` , `y = [1, 0, 0, 1, 1, 2, 1]`. <br>
# >
# > (i) Connect the points with the plot function and set both axes with the limits: -1 and 2. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
x = [0, 0, 1, 1, 0, 0.5, 1]
y = [1, 0, 0, 1, 1, 2, 1]
plt.plot(x, y)
plt.axis([-1, 2, -1, 2]);

# %% [markdown]
# ####
# The `plot` function also works with ***Pandas Series***. When working with a *DataFrame* you can simply extract some columns to create graphs. For example: `plt.plot(my_df['column1'], my_df['column2'])`. <br>
#
# The file './data/sales_data.csv' contains the monthly sales information of some products over a period of 3 years. <br>
#
# > (j) Read `'/content/sales_data.csv'` into a DataFrame. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
df = pd.read_csv('/content/sales_data.csv')
print(df.shape)
# Out:
# (24, 5)

# %% [markdown]
# ####
# > (k) Create a line chart from the number of sales of the first product (`'Product1'`) as a function of (`'Month'`). <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
plt.plot(df['Month'], df['Product1']);

# %% [markdown]
# ####
# The resulting graph shows a poorly readable X-axis due to the large number of markings compared to the image size. <br>
#
# The **pandas** library contains plot methods that use *Matplotlib* in the background to create charts directly from DataFrame columns quickly and optimized. They also allow you to directly add additional parameters such as a title, axis limits, or legends. For example: `df.plot(x=column1, y=column2, title="My Title", ylim=[100,700])` is sufficient to create a complete graph. <br>
#
# > (l) Use the `plot` method of **df** to display the monthly sales figures with an appropriate title. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
df.plot(x='Month', y='Product1', title="Sales per month");

# %% [markdown]
# ## 2. Multiple Line Charts, Line Styles and Legends
#
# <hr style="border-width:2px;border-color:#75DFC1">
#
# In this notebook, we will see how to draw multiple curves in the same chart and explore the formatting options provided by Matplotlib. <br>
#
# Multiple curves are particularly useful when you want to compare different data series or distributions in a single chart to highlight differences or similarities between these series. <br>
#
# <img src="https://drive.google.com/uc?id=1DFkBQxfm65FDGZhuywq_eUiuEkuBxQXP" style="height:350px">

# %% [markdown]
# To draw a line chart with multiple lines, you can call the **`plot`** function multiple times, like this: <br>
# ><code>plt.plot(<span style="color:red">x,y</span>)
# plt.plot(<span style="color:blue">u,v</span>)
# plt.plot(<span style="color:green">w,z</span>)</code>
#
# or simply use the following syntax: <br>
# ><code>plt.plot(<span style="color:red">x,y</span>,<span style="color:blue">u,v</span>,<span style="color:green">w,z</span>)</code>

# %% [markdown]
# #### 2.1 Tasks:
# > (a) Create in a list named **`t`** a sequence from 0 to 5 with a step size of 0.2 using the **`np.arange`** function. <br>
# >
# > (b) Draw in the same chart the functions $t$ , $t^2$ and $t^3$ and set the y-axis limits between 0 and 50. <br>
#
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i> &emsp;
# The command: <b>np.arange(a, b, p)</b> returns a 1D array with numbers between <b>a</b> and <b>b</b> (b excluded) with a step size of p.
# </div>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
t = np.arange(0,5,0.2)

plt.plot(t,t  ,t,t**2,  t,t**3)
# We draw (t,t), (t,t**2) and (t,t**3) in the same function

plt.ylim([0,50]);
# We set the y limit at [0,50]

# %% [markdown]
# ####
# Matplotlib also offers the possibility to change the style of elements in charts, which can be very useful to further distinguish them and even add additional meaning (such as a specific color). <br>
#
# For each pair (x,y) there is a third optional argument to set the style and color of the line. E.g. for a red "r" solid "-" line:<br>
#
# ><code>plt.plot(<span style="color:red">x,y</span>,<span>"-r"</span>)</code>
#
# Available line styles are: <br>
#
# | <p class="text-center">Line Styles</p> | <p class="text-center">Description</p> |
# |:---:|:---:|
# | <p class="text-center">'-'</p> | <p class="text-center">solid line</p> |
# | <p class="text-center">'--'</p> | <p class="text-center">dashed line</p> |
# | <p class="text-center">':'</p> | <p class="text-center">dotted line</p> |
# | <p class="text-center">'-.'</p> | <p class="text-center">mixture of dashes and dots</p> |
#
# Available colors are: <br>
#
# | <p class="text-center">Colors</p> | <p class="text-center">Description</p> |
# |:---:|:---:|
# | <p class="text-center">'b'</p> | <p class="text-center">blue</p> |
# | <p class="text-center">'g'</p> | <p class="text-center">green</p> |
# | <p class="text-center">'r'</p> | <p class="text-center">red</p> |
# | <p class="text-center">'c'</p> | <p class="text-center">cyan</p> |
# | <p class="text-center">'m'</p> | <p class="text-center">magenta</p> |
# | <p class="text-center">'y'</p> | <p class="text-center">yellow</p> |
# | <p class="text-center">'k'</p> | <p class="text-center">black</p> |
# | <p class="text-center">'w'</p> | <p class="text-center">white</p> |
#
# Color and style can be combined with each other. For example, the default format is 'b-', which is a blue solid line. <br>
#
# > (c) Redraw the three lines from the previous task with the following styles: dotted red line, solid green line and dashed blue line. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
t = np.arange(0,5,0.2)

plt.plot(t,t,':r', t,t**2,'-g', t,t**3, '--b')

plt.ylim([0,50])

plt.show()

# %% [markdown]
# ####
# It is also possible to add markers with symbols. You can add them to lines or even use them instead of lines. These symbols can be chained with the colors above. <br>
#
# Available markers are: <br>
#
# | <p class="text-center">Marker</p> | <p class="text-center">Description</p> |
# |:---:|:---:|
# | <p class="text-center">'.'</p> | <p class="text-center">point marker</p> |
# | <p class="text-center">','</p> | <p class="text-center">pixel marker</p> |
# | <p class="text-center">'o'</p> | <p class="text-center">circle marker</p> |
# | <p class="text-center">'v'</p> | <p class="text-center">triangle_down marker</p> |
# | <p class="text-center">'^'</p> | <p class="text-center">triangle_up marker</p> |
# | <p class="text-center">'<'</p> | <p class="text-center">triangle_left marker</p> |
# | <p class="text-center">'>'</p> | <p class="text-center">triangle_right marker</p> |
# | <p class="text-center">'s'</p> | <p class="text-center">square marker</p> |
# | <p class="text-center">'p'</p> | <p class="text-center">pentagon marker</p> |
# | <p class="text-center">'*'</p> | <p class="text-center">star marker</p> |
# | <p class="text-center">'h'</p> | <p class="text-center">hexagon1 marker</p> |
# | <p class="text-center">'H'</p> | <p class="text-center">hexagon2 marker</p> |
# | <p class="text-center">'+'</p> | <p class="text-center">plus marker</p> |
# | <p class="text-center">'x'</p> | <p class="text-center">x marker</p> |
# | <p class="text-center">'D'</p> | <p class="text-center">diamond marker</p> |
# | <p class="text-center">'d'</p> | <p class="text-center">thin_diamond marker</p> |
#
# You can specify the style of a line chart in **one string** in this order: the color, the line style and the markers. <br>
# For example: <br>
# * `"r-*"` for a red solid line with star markers <br>
# * `"y:d"` for a yellow dotted line with diamond markers, etc. <br>
#
# When drawing a line, it is also possible to adjust its width, thanks to the *`linewidth`* parameter of the `plot` function. <br>
# So the command: `plt.plot(x, y, "r--", linewidth=5, marker='o')` displays a red dashed line with width 5 and circle markers. <br>
#
# > (d) Redraw the last 3 lines, each with the following styles: yellow hexagon1 markers, green line with width 5 and blue line with diamond markers. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
t = np.arange(0,5,0.2)

plt.plot(t,t,'hy')
plt.plot(t,t**2,'g-', linewidth=5)
plt.plot(t,t**3,'b', marker='D')
plt.ylim([0,50])

plt.show()

# %% [markdown]
# ####
# It is possible to add another very important element for the readability of charts - legends - with the [legend](https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.legend) method, by assigning names to the curves in the `'label'` argument within the plot command. <br>
#
# The position of the legend can be chosen with the `loc` argument, which can be `'best'`, `'lower right'`, `'upper center'`, `'center left'`, etc. <br>
#
# It is also possible to add a grid to the chart with `plt.grid(True)`. <br>
#
# > (e) Draw in a chart with grid the following line charts: <br>
# >
# >    * 1) The points (50,2), (100,3), (150,7), (200,10) connected with a blue line of width 0.8 and markers '*' with label 'Path 1'. <br>
# >    * 2) The points (50,2), (100,7), (150,9), (200,10) connected with a blue line of width 0.8 and markers '+' with label 'Path 2'. <br>
# >
# > (f) Give the x-axis and y-axis the labels "Speed" and "Time". <br>
# >
# > (g) Show the legend of the chart. <br>

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
plt.grid(True)
plt.plot([50,100,150,200], [2,3,7,10], "b-*", linewidth=0.8, label="Path 1")
plt.plot([50,100,150,200], [2,7,9,10], "g-+", linewidth=0.8, label="Path 2")
plt.xlabel('Speed')
plt.ylabel('Time')
plt.legend();

# %% [markdown]
# ####
# With the built-in methods of Pandas DataFrames, you can also add style to the chart by using the same parameter names. <br>
#
# It is also possible to display multiple lines in the same chart by passing a list to the `y` parameter. <br>
#
# The `style` parameter can also receive a list to assign each line its own style. <br>
#
# Example: `my_df.plot(x=column1, y=[column2,column3], style=["r--", "c-+"])` <br>
#
# > (h) Read the file `"/content/sales_data.csv"`. <br>
# >
# > (i) Display in a chart the line charts for the columns "Product1" and "Product2" as a function of "Month". Add a different style for each line as well as the title "Sales per Month". <br>
#
# ```python

# %%
# Your solution:

# %% [markdown]
# #### Solution:

# %%
df = pd.read_csv("/content/sales_data.csv")

df.plot(x='Month', y=['Product1','Product2'], style=["m--", "c:."], title="Sales per month", linewidth=5);

# %% [markdown]
# ## Summary:
#
# - To create line charts with *Matplotlib*, we use the ```plt.plot()``` function, which works with ```lists```, ```numpy arrays```, and ```Pandas Series```. <br>
# - A single plot command can draw multiple lines by passing multiple x,y pairs: ```plt.plot(x1,y1, x2,y2, x3,y3)```. <br>
# - Matplotlib offers diverse formatting options for your plots: <br>
#
#     - Line styles ```'-', '--', ':', '-.'``` for different line types
#     - Colors ```'r', 'g', 'b', etc.``` for different lines
#     - Markers ```'o', '*', '+', etc.``` for data points
#     - Line width with ```linewidth``` for emphasizing certain lines <br>
#
#
# - For better readability of your charts, you can add various elements: <br>
#
#     - Legends with ```plt.legend()``` and the ```label``` parameter
#     - Axis labels with ```xlabel``` and ```ylabel```
#     - Titles with ```title```
#     - Grid with ```plt.grid(True)```
#     - Axis limits with ```xlim``` and ```ylim``` <br>
#
#
# - *Pandas* DataFrames offer simplified syntax for plotting with Matplotlib in the background: <br>
#
#     - Direct plotting of multiple columns with ```df.plot(x='column1', y=['column2', 'column3'])```
#     - Easy style customization with the ```style``` parameter
#     - Automatic legend creation based on column names <br>
